# %% [markdown]
# #Preprocessing and EDA#

# %%
import os
import librosa
import numpy as np
import pandas as pd
import requests
from google.colab import drive

drive.mount('/content/gdrive')  # Connect to your Google Drive account

data_dir = '/content/gdrive/MyDrive/audio_data2'  # Update with your data directory in Google Drive
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import requests
import json
import pandas as pd

# Species list
species_list = ['Grey francolin', 'Purple sunbird', 'Common Tailorbird', 'Red-vented Bulbul', 'Indian Bush Lark', 'Siberian Stonechat ', 'Bay-backed Shrike', 'Indian roller', 'Indian Peafowl', 'Plain Prinia']
species_list.append('Tawny Pipit')
species_list.append('Common Babbler')
species_list.append('White-eared Bulbul')
species_list.append('Tawny Pipit')
species_list.append("Wire-tailed Swallow")
species_list.append("Indian Black-lored Tit")
species_list.append("Northern Raven")

species_list.append("Hume's Leaf Warbler")
# Create empty dataframe
df = pd.DataFrame(columns=['id', 'gen', 'sp', 'ssp', 'en', 'rec', 'cnt', 'loc', 'lat', 'lng', 'alt', 'type', 'url', 'file', 'file-name', 'sono', 'lic', 'q', 'length', 'time', 'date', 'uploaded', 'also', 'rmk', 'bird-seen', 'playback-used'])

# Loop through species list and extract data
for species in species_list:
    query = f'https://www.xeno-canto.org/api/2/recordings?query={species}%20cnt:India'
    response = requests.get(query)
    if response.status_code == 200:
        data = response.json()
        temp_df = pd.json_normalize(data['recordings'])
        df = pd.concat([df, temp_df], ignore_index=True)

# Save as CSV
df.to_csv('indian_species.csv', index=False)

# %%
df=df [['id', 'gen', 'sp', 'ssp', 'en', 'rec', 'cnt', 'loc', 'lat', 'lng', 'alt', 'type', 'url', 'file', 'file-name', 'sono', 'lic', 'q', 'length', 'time', 'date', 'uploaded', 'also', 'rmk', 'bird-seen', 'playback-used']]

# %%
df
# Out:
#          id           gen             sp           ssp                   en  \
# 0    796874    Ortygornis  pondicerianus                     Grey Francolin
# 1    775466    Ortygornis  pondicerianus                     Grey Francolin
# 2    706170    Ortygornis  pondicerianus  interpositus       Grey Francolin
# 3    667224    Ortygornis  pondicerianus                     Grey Francolin
# 4    667223    Ortygornis  pondicerianus                     Grey Francolin
# ..      ...           ...            ...           ...                  ...
# 666  105580  Phylloscopus          humei                Hume's Leaf Warbler
# 667   91910  Phylloscopus          humei                Hume's Leaf Warbler
# 668   73381  Phylloscopus          humei         humei  Hume's Leaf Warbler
# 669   19290  Phylloscopus          humei     mandellii  Hume's Leaf Warbler
# 670  116654  Phylloscopus          humei     mandellii  Hume's Leaf Warbler
#
#                   rec    cnt  \
# 0     Barry Edmonston  India
# 1    Jelle Scharringa  India
# 2     Kousheyo Bagchi  India
# 3    Jelle Scharringa  India
# 4    Jelle Scharringa  India
# ..                ...    ...
# 666       Ante Strand  India
# 667      Ramit Singal  India
# 668       Mike Nelson  India
# 669      Craig Robson  India
# 670       Mike Nelson  India
#
#                                                    loc       lat       lng  \
# 0    Jaisalmer (near  Kanoi), Jodhpur Division, Raj...   26.8209   70.5272
# 1                       Ghasaula, Bharatpur, Rajasthan   27.1599   77.5418
# 2      Barshul Birding Hotspot, Bardhaman, West Bengal    23.175   87.9566
# 3               Shreenagar Rural, Bharatpur, Rajasthan   27.1536   77.5465
# 4               Shreenagar Rural, Bharatpur, Rajasthan   27.1536   77.5465
# ..                                                 ...       ...       ...
# 666                                Harike Lake, Punjab   31.1489   74.9448
# 667                                              Delhi   28.6478   77.2098
# 668                           Sultanpur Bird Sanctuary    28.464    76.893
# 669                                           Shillong  25.56892  91.88313
# 670                   Wildgrass Lodge, Golaghat, Assam   26.5949   93.4516
#
#      ...                                           lic  q length    time  \
# 0    ...  //creativecommons.org/licenses/by-nc-sa/4.0/  A   0:37   08:00
# 1    ...  //creativecommons.org/licenses/by-nc-sa/4.0/  A   0:09   17:15
# 2    ...  //creativecommons.org/licenses/by-nc-nd/4.0/  A   0:11   16:00
# 3    ...  //creativecommons.org/licenses/by-nc-sa/4.0/  A   1:38   18:00
# 4    ...  //creativecommons.org/licenses/by-nc-sa/4.0/  A   0:45   11:30
# ..   ...                                           ... ..    ...     ...
# 666  ...  //creativecommons.org/licenses/by-nc-nd/2.5/  C   0:19       ?
# 667  ...  //creativecommons.org/licenses/by-nc-nd/2.5/  C   0:05   09:15
# 668  ...  //creativecommons.org/licenses/by-nc-sa/3.0/  C   0:18  4:00pm
# 669  ...  //creativecommons.org/licenses/by-nc-nd/2.5/  C   0:33     ?:?
# 670  ...  //creativecommons.org/licenses/by-nc-sa/3.0/  D   0:17   07:00
#
#            date    uploaded  \
# 0    2023-01-29  2023-04-29
# 1    1986-02-15  2023-01-14
# 2    2021-10-03  2022-03-05
# 3    1986-02-11  2021-08-09
# 4    1986-02-11  2021-08-09
# ..          ...         ...
# 666  2011-02-05  2012-07-10
# 667  2011-12-22  2011-12-22
# 668  2011-03-06  2011-03-21
# 669  0000-00-00  2008-11-20
# 670  2012-11-26  2013-01-05
#
#                                                   also  \
# 0                                                   []
# 1        [Psittacula krameri, Spilopelia senegalensis]
# 2                                                   []
# 3                      [Ficedula parva, Argya striata]
# 4    [Corvus splendens, Psittacula krameri, Spilope...
# ..                                                 ...
# 666                                                 []
# 667                                                 []
# 668                                                 []
# 669                                                 []
# 670                                                 []
#
#                                                    rmk bird-seen playback-used
# 0                                                            yes            no
# 1                              At Eastern Boundary\r\n       yes            no
# 2    Dry vegetations around R. Damodar. Eastern edg...   unknown       unknown
# 3    Several birds on ground calling from many dire...       yes            no
# 4    Several birds on ground calling from different...       yes            no
# ..                                                 ...       ...           ...
# 666                                                      unknown       unknown
# 667                              Traffic in background   unknown       unknown
# 668   Several seen in the open forest along the trails       yes            no
# 669                                                      unknown       unknown
# 670                   Seen in the grounds of the lodge       yes            no
#
# [671 rows x 26 columns]

# %%
np.unique(df['type'])
# Out:
# array(['', '?', 'aberrant, call, song', 'aberrant, hatchling or nestling',
#        'aberrant, song', 'alarm call', 'alarm call, begging call',
#        'alarm call, call', 'alarm call, call, flight call, song',
#        'alarm call, call, song', 'alarm call, flight call',
#        'begging call', 'begging call, two wheeler', 'call',
#        'call, allrm call', 'call, call or song?', 'call, communication',
#        'call, drumming', 'call, duet', 'call, flight call',
#        'call, flight call, song', 'call, song',
#        'call, song, call and song', 'call, song, contact call',
#        'call, song, thermal power station in service',
#        'call, teaching nestling how we call', 'call?', 'duet, song',
#        'fight of 2 males', 'flight call', 'flight call, song',
#        'imitation, song, imitation tits (parus spp) song', 'song',
#        'song, immature male', 'song, rock bush', 'song, subsong',
#        'uncertain'], dtype=object)

# %%
df.to_csv('indian_species.csv', index=False)

# %%
df = pd.DataFrame(df[df['type'].str.contains('call')])

# %%
df['en'].unique()
# Out:
# array(['Grey Francolin', 'Purple Sunbird', 'Common Tailorbird',
#        'Red-vented Bulbul', 'Indian Bush Lark', 'Siberian Stonechat',
#        'Bay-backed Shrike', 'Indian Roller', 'Indian Peafowl',
#        'Plain Prinia', 'Tawny Pipit', 'Common Babbler',
#        'White-eared Bulbul', 'Wire-tailed Swallow',
#        'Indian Black-lored Tit', 'Northern Raven', "Hume's Leaf Warbler"],
#       dtype=object)

# %%
len(df['en'].unique())
# Out:
# 17

# %%
df
# Out:
#          id           gen             sp        ssp                   en  \
# 0    796874    Ortygornis  pondicerianus                  Grey Francolin
# 7    472717    Ortygornis  pondicerianus                  Grey Francolin
# 8    459199    Ortygornis  pondicerianus                  Grey Francolin
# 9    441379    Ortygornis  pondicerianus                  Grey Francolin
# 10   351857    Ortygornis  pondicerianus                  Grey Francolin
# ..      ...           ...            ...        ...                  ...
# 666  105580  Phylloscopus          humei             Hume's Leaf Warbler
# 667   91910  Phylloscopus          humei             Hume's Leaf Warbler
# 668   73381  Phylloscopus          humei      humei  Hume's Leaf Warbler
# 669   19290  Phylloscopus          humei  mandellii  Hume's Leaf Warbler
# 670  116654  Phylloscopus          humei  mandellii  Hume's Leaf Warbler
#
#                         rec    cnt  \
# 0           Barry Edmonston  India
# 7             Peter Boesman  India
# 8            Vivek Puliyeri  India
# 9    Sreekumar Chirukandoth  India
# 10           Oscar Campbell  India
# ..                      ...    ...
# 666             Ante Strand  India
# 667            Ramit Singal  India
# 668             Mike Nelson  India
# 669            Craig Robson  India
# 670             Mike Nelson  India
#
#                                                    loc       lat       lng  \
# 0    Jaisalmer (near  Kanoi), Jodhpur Division, Raj...   26.8209   70.5272
# 7         Keoladeo National Park, Bharatpur, Rajasthan   27.1593   77.5232
# 8                      IIT Madras, Chennai, Tamil Nadu   12.9912   80.2363
# 9                    Bareilly, Bareilly, Uttar Pradesh   28.3967   79.4319
# 10                            Bari, Udaipur, Rajasthan   24.6227   73.6597
# ..                                                 ...       ...       ...
# 666                                Harike Lake, Punjab   31.1489   74.9448
# 667                                              Delhi   28.6478   77.2098
# 668                           Sultanpur Bird Sanctuary    28.464    76.893
# 669                                           Shillong  25.56892  91.88313
# 670                   Wildgrass Lodge, Golaghat, Assam   26.5949   93.4516
#
#      ...                                           lic  q length    time  \
# 0    ...  //creativecommons.org/licenses/by-nc-sa/4.0/  A   0:37   08:00
# 7    ...  //creativecommons.org/licenses/by-nc-nd/4.0/  A   0:16   07:30
# 8    ...  //creativecommons.org/licenses/by-nc-sa/4.0/  A   0:12   07:00
# 9    ...  //creativecommons.org/licenses/by-nc-sa/4.0/  A   0:07   08:00
# 10   ...  //creativecommons.org/licenses/by-nc-sa/4.0/  A   0:21   08:30
# ..   ...                                           ... ..    ...     ...
# 666  ...  //creativecommons.org/licenses/by-nc-nd/2.5/  C   0:19       ?
# 667  ...  //creativecommons.org/licenses/by-nc-nd/2.5/  C   0:05   09:15
# 668  ...  //creativecommons.org/licenses/by-nc-sa/3.0/  C   0:18  4:00pm
# 669  ...  //creativecommons.org/licenses/by-nc-nd/2.5/  C   0:33     ?:?
# 670  ...  //creativecommons.org/licenses/by-nc-sa/3.0/  D   0:17   07:00
#
#            date    uploaded                also  \
# 0    2023-01-29  2023-04-29                  []
# 7    2019-04-06  2019-05-10                  []
# 8    2019-02-25  2019-02-25                  []
# 9    2018-10-14  2018-11-05  [Corvus splendens]
# 10   2016-12-24  2017-01-22                  []
# ..          ...         ...                 ...
# 666  2011-02-05  2012-07-10                  []
# 667  2011-12-22  2011-12-22                  []
# 668  2011-03-06  2011-03-21                  []
# 669  0000-00-00  2008-11-20                  []
# 670  2012-11-26  2013-01-05                  []
#
#                                                    rmk bird-seen playback-used
# 0                                                            yes            no
# 7                                                        unknown       unknown
# 8                                                             no            no
# 9                An individual calling from the fields       yes            no
# 10   Calling from dense scrub on edge of field on b...        no            no
# ..                                                 ...       ...           ...
# 666                                                      unknown       unknown
# 667                              Traffic in background   unknown       unknown
# 668   Several seen in the open forest along the trails       yes            no
# 669                                                      unknown       unknown
# 670                   Seen in the grounds of the lodge       yes            no
#
# [462 rows x 26 columns]

# %%
df=df.drop(['ssp'], axis=1)

# %%
df2=df.drop(['rmk'],axis=1)
df2.isnull().sum()
# Out:
# id                 0
# gen                0
# sp                 0
# en                 0
# rec                0
# cnt                0
# loc                0
# lat                4
# lng                4
# alt                0
# type               0
# url                0
# file               0
# file-name          0
# sono             462
# lic                0
# q                  0
# length             0
# time               0
# date               0
# uploaded           0
# also               0
# bird-seen          0
# playback-used      0
# dtype: int64

# %%
df2
# Out:
#          id           gen             sp                   en  \
# 0    796874    Ortygornis  pondicerianus       Grey Francolin
# 7    472717    Ortygornis  pondicerianus       Grey Francolin
# 8    459199    Ortygornis  pondicerianus       Grey Francolin
# 9    441379    Ortygornis  pondicerianus       Grey Francolin
# 10   351857    Ortygornis  pondicerianus       Grey Francolin
# ..      ...           ...            ...                  ...
# 666  105580  Phylloscopus          humei  Hume's Leaf Warbler
# 667   91910  Phylloscopus          humei  Hume's Leaf Warbler
# 668   73381  Phylloscopus          humei  Hume's Leaf Warbler
# 669   19290  Phylloscopus          humei  Hume's Leaf Warbler
# 670  116654  Phylloscopus          humei  Hume's Leaf Warbler
#
#                         rec    cnt  \
# 0           Barry Edmonston  India
# 7             Peter Boesman  India
# 8            Vivek Puliyeri  India
# 9    Sreekumar Chirukandoth  India
# 10           Oscar Campbell  India
# ..                      ...    ...
# 666             Ante Strand  India
# 667            Ramit Singal  India
# 668             Mike Nelson  India
# 669            Craig Robson  India
# 670             Mike Nelson  India
#
#                                                    loc       lat       lng  \
# 0    Jaisalmer (near  Kanoi), Jodhpur Division, Raj...   26.8209   70.5272
# 7         Keoladeo National Park, Bharatpur, Rajasthan   27.1593   77.5232
# 8                      IIT Madras, Chennai, Tamil Nadu   12.9912   80.2363
# 9                    Bareilly, Bareilly, Uttar Pradesh   28.3967   79.4319
# 10                            Bari, Udaipur, Rajasthan   24.6227   73.6597
# ..                                                 ...       ...       ...
# 666                                Harike Lake, Punjab   31.1489   74.9448
# 667                                              Delhi   28.6478   77.2098
# 668                           Sultanpur Bird Sanctuary    28.464    76.893
# 669                                           Shillong  25.56892  91.88313
# 670                   Wildgrass Lodge, Golaghat, Assam   26.5949   93.4516
#
#      alt  ... sono                                           lic  q length  \
# 0    200  ...  NaN  //creativecommons.org/licenses/by-nc-sa/4.0/  A   0:37
# 7         ...  NaN  //creativecommons.org/licenses/by-nc-nd/4.0/  A   0:16
# 8     10  ...  NaN  //creativecommons.org/licenses/by-nc-sa/4.0/  A   0:12
# 9    180  ...  NaN  //creativecommons.org/licenses/by-nc-sa/4.0/  A   0:07
# 10   600  ...  NaN  //creativecommons.org/licenses/by-nc-sa/4.0/  A   0:21
# ..   ...  ...  ...                                           ... ..    ...
# 666    ?  ...  NaN  //creativecommons.org/licenses/by-nc-nd/2.5/  C   0:19
# 667  216  ...  NaN  //creativecommons.org/licenses/by-nc-nd/2.5/  C   0:05
# 668  200  ...  NaN  //creativecommons.org/licenses/by-nc-sa/3.0/  C   0:18
# 669    ?  ...  NaN  //creativecommons.org/licenses/by-nc-nd/2.5/  C   0:33
# 670   90  ...  NaN  //creativecommons.org/licenses/by-nc-sa/3.0/  D   0:17
#
#        time        date    uploaded                also bird-seen  \
# 0     08:00  2023-01-29  2023-04-29                  []       yes
# 7     07:30  2019-04-06  2019-05-10                  []   unknown
# 8     07:00  2019-02-25  2019-02-25                  []        no
# 9     08:00  2018-10-14  2018-11-05  [Corvus splendens]       yes
# 10    08:30  2016-12-24  2017-01-22                  []        no
# ..      ...         ...         ...                 ...       ...
# 666       ?  2011-02-05  2012-07-10                  []   unknown
# 667   09:15  2011-12-22  2011-12-22                  []   unknown
# 668  4:00pm  2011-03-06  2011-03-21                  []       yes
# 669     ?:?  0000-00-00  2008-11-20                  []   unknown
# 670   07:00  2012-11-26  2013-01-05                  []       yes
#
#     playback-used
# 0              no
# 7         unknown
# 8              no
# 9              no
# 10             no
# ..            ...
# 666       unknown
# 667       unknown
# 668            no
# 669       unknown
# 670            no
#
# [462 rows x 24 columns]

# %%
df4=df2[["id","en","loc","lat","lng","file","length"]]
df4
# Out:
#          id                   en  \
# 0    796874       Grey Francolin
# 7    472717       Grey Francolin
# 8    459199       Grey Francolin
# 9    441379       Grey Francolin
# 10   351857       Grey Francolin
# ..      ...                  ...
# 666  105580  Hume's Leaf Warbler
# 667   91910  Hume's Leaf Warbler
# 668   73381  Hume's Leaf Warbler
# 669   19290  Hume's Leaf Warbler
# 670  116654  Hume's Leaf Warbler
#
#                                                    loc       lat       lng  \
# 0    Jaisalmer (near  Kanoi), Jodhpur Division, Raj...   26.8209   70.5272
# 7         Keoladeo National Park, Bharatpur, Rajasthan   27.1593   77.5232
# 8                      IIT Madras, Chennai, Tamil Nadu   12.9912   80.2363
# 9                    Bareilly, Bareilly, Uttar Pradesh   28.3967   79.4319
# 10                            Bari, Udaipur, Rajasthan   24.6227   73.6597
# ..                                                 ...       ...       ...
# 666                                Harike Lake, Punjab   31.1489   74.9448
# 667                                              Delhi   28.6478   77.2098
# 668                           Sultanpur Bird Sanctuary    28.464    76.893
# 669                                           Shillong  25.56892  91.88313
# 670                   Wildgrass Lodge, Golaghat, Assam   26.5949   93.4516
#
#                                        file length
# 0    https://xeno-canto.org/796874/download   0:37
# 7    https://xeno-canto.org/472717/download   0:16
# 8    https://xeno-canto.org/459199/download   0:12
# 9    https://xeno-canto.org/441379/download   0:07
# 10   https://xeno-canto.org/351857/download   0:21
# ..                                      ...    ...
# 666  https://xeno-canto.org/105580/download   0:19
# 667   https://xeno-canto.org/91910/download   0:05
# 668   https://xeno-canto.org/73381/download   0:18
# 669   https://xeno-canto.org/19290/download   0:33
# 670  https://xeno-canto.org/116654/download   0:17
#
# [462 rows x 7 columns]

# %%
df4['lng'] = pd.to_numeric(df4['lng'])
# Out:
# <ipython-input-68-668c6f565b72>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['lng'] = pd.to_numeric(df4['lng'])

# %%
df4['lat'] = pd.to_numeric(df4['lat'])
# Out:
# <ipython-input-69-8b213974713b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['lat'] = pd.to_numeric(df4['lat'])

# %%
df4
# Out:
#          id                   en  \
# 0    796874       Grey Francolin
# 7    472717       Grey Francolin
# 8    459199       Grey Francolin
# 9    441379       Grey Francolin
# 10   351857       Grey Francolin
# ..      ...                  ...
# 666  105580  Hume's Leaf Warbler
# 667   91910  Hume's Leaf Warbler
# 668   73381  Hume's Leaf Warbler
# 669   19290  Hume's Leaf Warbler
# 670  116654  Hume's Leaf Warbler
#
#                                                    loc       lat       lng  \
# 0    Jaisalmer (near  Kanoi), Jodhpur Division, Raj...  26.82090  70.52720
# 7         Keoladeo National Park, Bharatpur, Rajasthan  27.15930  77.52320
# 8                      IIT Madras, Chennai, Tamil Nadu  12.99120  80.23630
# 9                    Bareilly, Bareilly, Uttar Pradesh  28.39670  79.43190
# 10                            Bari, Udaipur, Rajasthan  24.62270  73.65970
# ..                                                 ...       ...       ...
# 666                                Harike Lake, Punjab  31.14890  74.94480
# 667                                              Delhi  28.64780  77.20980
# 668                           Sultanpur Bird Sanctuary  28.46400  76.89300
# 669                                           Shillong  25.56892  91.88313
# 670                   Wildgrass Lodge, Golaghat, Assam  26.59490  93.45160
#
#                                        file length
# 0    https://xeno-canto.org/796874/download   0:37
# 7    https://xeno-canto.org/472717/download   0:16
# 8    https://xeno-canto.org/459199/download   0:12
# 9    https://xeno-canto.org/441379/download   0:07
# 10   https://xeno-canto.org/351857/download   0:21
# ..                                      ...    ...
# 666  https://xeno-canto.org/105580/download   0:19
# 667   https://xeno-canto.org/91910/download   0:05
# 668   https://xeno-canto.org/73381/download   0:18
# 669   https://xeno-canto.org/19290/download   0:33
# 670  https://xeno-canto.org/116654/download   0:17
#
# [462 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your dataframe is called df2 and the duration column is called "duration"
duration_data = df4["length"]

# Print minimum and maximum duration
print("Minimum duration:", duration_data.min())
print("Maximum duration:", duration_data.max())

# Create histogram with KDE plot
sns.histplot(duration_data, bins=50, kde=True)

# Set x and y axis labels
plt.xlabel("Duration (seconds)")
plt.ylabel("Count")

# Show the plot
plt.show()
# Out:
# Minimum duration: 0:00
# Maximum duration: 3:21

# %%
def is_desert(latitude, longitude):
    # Check if the latitude and longitude fall within the range of the Thar Desert
    if latitude >= 24.6 and latitude <= 30.5 and longitude >= 68.7 and longitude <= 75.3:
        return 1
    else:
        return 0

# Apply the is_desert function to the latitude and longitude columns
df4['Desert/Non-Desert'] = np.vectorize(is_desert)(df4['lat'], df4['lng'])

df5=df4.drop(['loc','lat','lng'],axis=1)
df5
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2387: RuntimeWarning: invalid value encountered in is_desert (vectorized)
#   outputs = ufunc(*inputs)
# <ipython-input-72-6c842a43dd23>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Desert/Non-Desert'] = np.vectorize(is_desert)(df4['lat'], df4['lng'])
#          id                   en                                    file  \
# 0    796874       Grey Francolin  https://xeno-canto.org/796874/download
# 7    472717       Grey Francolin  https://xeno-canto.org/472717/download
# 8    459199       Grey Francolin  https://xeno-canto.org/459199/download
# 9    441379       Grey Francolin  https://xeno-canto.org/441379/download
# 10   351857       Grey Francolin  https://xeno-canto.org/351857/download
# ..      ...                  ...                                     ...
# 666  105580  Hume's Leaf Warbler  https://xeno-canto.org/105580/download
# 667   91910  Hume's Leaf Warbler   https://xeno-canto.org/91910/download
# 668   73381  Hume's Leaf Warbler   https://xeno-canto.org/73381/download
# 669   19290  Hume's Leaf Warbler   https://xeno-canto.org/19290/download
# 670  116654  Hume's Leaf Warbler  https://xeno-canto.org/116654/download
#
#     length  Desert/Non-Desert
# 0     0:37                  1
# 7     0:16                  0
# 8     0:12                  0
# 9     0:07                  0
# 10    0:21                  1
# ..     ...                ...
# 666   0:19                  0
# 667   0:05                  0
# 668   0:18                  0
# 669   0:33                  0
# 670   0:17                  0
#
# [462 rows x 5 columns]

# %%
df5.isnull().sum()
# Out:
# id                   0
# en                   0
# file                 0
# length               0
# Desert/Non-Desert    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Assuming your dataframe is called df5 and the "desert/non desert" column is called "label"
label_counts = df5["Desert/Non-Desert"].value_counts()

# Create bar graph
plt.bar(label_counts.index, label_counts.values)

# Set x and y axis labels
plt.xlabel("Label")
plt.ylabel("Count")

# Set x axis tick labels
plt.xticks([0, 1], ["Non-Desert", "Desert"])

# Show the plot
plt.show()

# %%
desert_rows = df5[df5["Desert/Non-Desert"] == 1]
print("Rows with Desert label:\n", desert_rows)
# Out:
# Rows with Desert label:
#           id                      en                                    file  \
# 0    796874          Grey Francolin  https://xeno-canto.org/796874/download
# 10   351857          Grey Francolin  https://xeno-canto.org/351857/download
# 12   167566          Grey Francolin  https://xeno-canto.org/167566/download
# 28   308191          Grey Francolin  https://xeno-canto.org/308191/download
# 29   308183          Grey Francolin  https://xeno-canto.org/308183/download
# 34   165833          Grey Francolin  https://xeno-canto.org/165833/download
# 35   149584          Grey Francolin  https://xeno-canto.org/149584/download
# 36   149582          Grey Francolin  https://xeno-canto.org/149582/download
# 37   129278          Grey Francolin  https://xeno-canto.org/129278/download
# 69   460278          Purple Sunbird  https://xeno-canto.org/460278/download
# 86   165447          Purple Sunbird  https://xeno-canto.org/165447/download
# 88   149562          Purple Sunbird  https://xeno-canto.org/149562/download
# 89   149561          Purple Sunbird  https://xeno-canto.org/149561/download
# 110  308260          Purple Sunbird  https://xeno-canto.org/308260/download
# 185  460275       Common Tailorbird  https://xeno-canto.org/460275/download
# 317  308261       Red-vented Bulbul  https://xeno-canto.org/308261/download
# 329  149559       Red-vented Bulbul  https://xeno-canto.org/149559/download
# 434  165857          Indian Peafowl  https://xeno-canto.org/165857/download
# 454  104137          Indian Peafowl  https://xeno-canto.org/104137/download
# 515  149575             Tawny Pipit  https://xeno-canto.org/149575/download
# 538  149581          Common Babbler  https://xeno-canto.org/149581/download
# 542  541885          Common Babbler  https://xeno-canto.org/541885/download
# 569  149575             Tawny Pipit  https://xeno-canto.org/149575/download
# 579  213115     Wire-tailed Swallow  https://xeno-canto.org/213115/download
# 580  213114     Wire-tailed Swallow  https://xeno-canto.org/213114/download
# 594  308258  Indian Black-lored Tit  https://xeno-canto.org/308258/download
# 602  529855  Indian Black-lored Tit  https://xeno-canto.org/529855/download
# 604  166338          Northern Raven  https://xeno-canto.org/166338/download
# 605  166337          Northern Raven  https://xeno-canto.org/166337/download
# 606  166336          Northern Raven  https://xeno-canto.org/166336/download
# 607  166335          Northern Raven  https://xeno-canto.org/166335/download
# 636  529852     Hume's Leaf Warbler  https://xeno-canto.org/529852/download
# 641  460283     Hume's Leaf Warbler  https://xeno-canto.org/460283/download
# 642  460274     Hume's Leaf Warbler  https://xeno-canto.org/460274/download
#
#     length  Desert/Non-Desert
# 0     0:37                  1
# 10    0:21                  1
# 12    0:10                  1
# 28    0:13                  1
# 29    0:25                  1
# 34    0:58                  1
# 35    1:09                  1
# 36    1:17                  1
# 37    0:18                  1
# 69    0:34                  1
# 86    0:40                  1
# 88    0:37                  1
# 89    0:24                  1
# 110   0:19                  1
# 185   0:45                  1
# 317   0:27                  1
# 329   0:19                  1
# 434   1:57                  1
# 454   0:05                  1
# 515   0:01                  1
# 538   2:00                  1
# 542   0:26                  1
# 569   0:01                  1
# 579   0:53                  1
# 580   0:20                  1
# 594   0:42                  1
# 602   0:26                  1
# 604   0:36                  1
# 605   0:41                  1
# 606   1:00                  1
# 607   0:17                  1
# 636   0:30                  1
# 641   0:15                  1
# 642   0:18                  1

# %%
bird_names = desert_rows["en"].unique()


bird_counts = {}


for bird in bird_names:
    count = desert_rows[desert_rows["en"] == bird].shape[0]
    bird_counts[bird] = count

for bird, count in bird_counts.items():
    print(f"{bird}: {count}")
# Out:
# Grey Francolin: 9
# Purple Sunbird: 5
# Common Tailorbird: 1
# Red-vented Bulbul: 2
# Indian Peafowl: 2
# Tawny Pipit: 2
# Common Babbler: 2
# Wire-tailed Swallow: 2
# Indian Black-lored Tit: 2
# Northern Raven: 4
# Hume's Leaf Warbler: 3

# %%
# !pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wget in /usr/local/lib/python3.10/dist-packages (3.2)

# %%
import wget

# %%
download_path = data_dir

# %%
df5
# Out:
#          id                   en                                    file  \
# 0    796874       Grey Francolin  https://xeno-canto.org/796874/download
# 7    472717       Grey Francolin  https://xeno-canto.org/472717/download
# 8    459199       Grey Francolin  https://xeno-canto.org/459199/download
# 9    441379       Grey Francolin  https://xeno-canto.org/441379/download
# 10   351857       Grey Francolin  https://xeno-canto.org/351857/download
# ..      ...                  ...                                     ...
# 666  105580  Hume's Leaf Warbler  https://xeno-canto.org/105580/download
# 667   91910  Hume's Leaf Warbler   https://xeno-canto.org/91910/download
# 668   73381  Hume's Leaf Warbler   https://xeno-canto.org/73381/download
# 669   19290  Hume's Leaf Warbler   https://xeno-canto.org/19290/download
# 670  116654  Hume's Leaf Warbler  https://xeno-canto.org/116654/download
#
#     length  Desert/Non-Desert
# 0     0:37                  1
# 7     0:16                  0
# 8     0:12                  0
# 9     0:07                  0
# 10    0:21                  1
# ..     ...                ...
# 666   0:19                  0
# 667   0:05                  0
# 668   0:18                  0
# 669   0:33                  0
# 670   0:17                  0
#
# [462 rows x 5 columns]

# %%
for index, row in df5.iterrows():
    xc_id = row['id']
    audio_url = row['file']
    if audio_url:
        filename = f"{xc_id}.mp3"
        filepath = os.path.join(download_path, filename)
        if not os.path.exists(filepath):
            print(f"Downloading audio {xc_id}...")
            wget.download(audio_url, filepath)
        else:
            print(f"Audio {xc_id} already downloaded.")
# Out:
# Audio 796874 already downloaded.
# Audio 472717 already downloaded.
# Audio 459199 already downloaded.
# Audio 441379 already downloaded.
# Audio 351857 already downloaded.
# Audio 337047 already downloaded.
# Audio 167566 already downloaded.
# Audio 149685 already downloaded.
# Audio 149684 already downloaded.
# Audio 94589 already downloaded.
# Audio 575657 already downloaded.
# Audio 474849 already downloaded.
# Audio 469359 already downloaded.
# Audio 459288 already downloaded.
# Audio 459287 already downloaded.
# Audio 451799 already downloaded.
# Audio 406118 already downloaded.
# Audio 334051 already downloaded.
# Audio 332453 already downloaded.
# Audio 308191 already downloaded.
# Audio 308183 already downloaded.
# Audio 199108 already downloaded.
# Audio 194204 already downloaded.
# Audio 166155 already downloaded.
# Audio 165833 already downloaded.
# Audio 149584 already downloaded.
# Audio 149582 already downloaded.
# Audio 129278 already downloaded.
# Audio 619357 already downloaded.
# Audio 442342 already downloaded.
# Audio 74555 already downloaded.
# Audio 21668 already downloaded.
# Audio 308571 already downloaded.
# Audio 788187 already downloaded.
# Audio 651998 already downloaded.
# Audio 651996 already downloaded.
# Audio 651988 already downloaded.
# Audio 460278 already downloaded.
# Audio 460182 already downloaded.
# Audio 454341 already downloaded.
# Audio 453728 already downloaded.
# Audio 453304 already downloaded.
# Audio 404206 already downloaded.
# Audio 369090 already downloaded.
# Audio 192187 already downloaded.
# Audio 192005 already downloaded.
# Audio 190895 already downloaded.
# Audio 187436 already downloaded.
# Audio 166255 already downloaded.
# Audio 165447 already downloaded.
# Audio 149750 already downloaded.
# Audio 149562 already downloaded.
# Audio 149561 already downloaded.
# Audio 111516 already downloaded.
# Audio 73048 already downloaded.
# Audio 574321 already downloaded.
# Audio 467418 already downloaded.
# Audio 452272 already downloaded.
# Audio 406121 already downloaded.
# Audio 406119 already downloaded.
# Audio 336746 already downloaded.
# Audio 331240 already downloaded.
# Audio 314406 already downloaded.
# Audio 314401 already downloaded.
# Audio 314009 already downloaded.
# Audio 308260 already downloaded.
# Audio 116822 already downloaded.
# Audio 116821 already downloaded.
# Audio 116820 already downloaded.
# Audio 94585 already downloaded.
# Audio 74150 already downloaded.
# Audio 74149 already downloaded.
# Audio 30661 already downloaded.
# Audio 541655 already downloaded.
# Audio 405830 already downloaded.
# Audio 286862 already downloaded.
# Audio 195584 already downloaded.
# Audio 779579 already downloaded.
# Audio 763953 already downloaded.
# Audio 754470 already downloaded.
# Audio 656017 already downloaded.
# Audio 594968 already downloaded.
# Audio 472857 already downloaded.
# Audio 460175 already downloaded.
# Audio 454040 already downloaded.
# Audio 433062 already downloaded.
# Audio 433060 already downloaded.
# Audio 401794 already downloaded.
# Audio 370329 already downloaded.
# Audio 171263 already downloaded.
# Audio 161260 already downloaded.
# Audio 161259 already downloaded.
# Audio 149689 already downloaded.
# Audio 149307 already downloaded.
# Audio 90833 already downloaded.
# Audio 90549 already downloaded.
# Audio 44794 already downloaded.
# Audio 21133 already downloaded.
# Audio 787330 already downloaded.
# Audio 577284 already downloaded.
# Audio 547602 already downloaded.
# Audio 547441 already downloaded.
# Audio 541295 already downloaded.
# Audio 540316 already downloaded.
# Audio 500734 already downloaded.
# Audio 500616 already downloaded.
# Audio 489159 already downloaded.
# Audio 469358 already downloaded.
# Audio 460275 already downloaded.
# Audio 460146 already downloaded.
# Audio 459289 already downloaded.
# Audio 442340 already downloaded.
# Audio 433061 already downloaded.
# Audio 432090 already downloaded.
# Audio 426730 already downloaded.
# Audio 419830 already downloaded.
# Audio 410318 already downloaded.
# Audio 402240 already downloaded.
# Audio 402080 already downloaded.
# Audio 393237 already downloaded.
# Audio 393229 already downloaded.
# Audio 388244 already downloaded.
# Audio 327939 already downloaded.
# Audio 325428 already downloaded.
# Audio 324989 already downloaded.
# Audio 318990 already downloaded.
# Audio 313092 already downloaded.
# Audio 312083 already downloaded.
# Audio 308578 already downloaded.
# Audio 276808 already downloaded.
# Audio 276807 already downloaded.
# Audio 241798 already downloaded.
# Audio 241382 already downloaded.
# Audio 211612 already downloaded.
# Audio 195589 already downloaded.
# Audio 195263 already downloaded.
# Audio 194309 already downloaded.
# Audio 190898 already downloaded.
# Audio 190897 already downloaded.
# Audio 187128 already downloaded.
# Audio 170592 already downloaded.
# Audio 149690 already downloaded.
# Audio 149688 already downloaded.
# Audio 122978 already downloaded.
# Audio 118008 already downloaded.
# Audio 116533 already downloaded.
# Audio 116532 already downloaded.
# Audio 116531 already downloaded.
# Audio 116529 already downloaded.
# Audio 116528 already downloaded.
# Audio 741500 already downloaded.
# Audio 633050 already downloaded.
# Audio 584316 already downloaded.
# Audio 536041 already downloaded.
# Audio 239910 already downloaded.
# Audio 209053 already downloaded.
# Audio 209010 already downloaded.
# Audio 190896 already downloaded.
# Audio 187127 already downloaded.
# Audio 86570 already downloaded.
# Audio 24073 already downloaded.
# Audio 455328 already downloaded.
# Audio 404376 already downloaded.
# Audio 402841 already downloaded.
# Audio 424135 already downloaded.
# Audio 741596 already downloaded.
# Audio 590312 already downloaded.
# Audio 578600 already downloaded.
# Audio 573352 already downloaded.
# Audio 573349 already downloaded.
# Audio 573348 already downloaded.
# Audio 573347 already downloaded.
# Audio 541611 already downloaded.
# Audio 529859 already downloaded.
# Audio 448176 already downloaded.
# Audio 441581 already downloaded.
# Audio 428402 already downloaded.
# Audio 404225 already downloaded.
# Audio 392133 already downloaded.
# Audio 352142 already downloaded.
# Audio 209007 already downloaded.
# Audio 207094 already downloaded.
# Audio 190899 already downloaded.
# Audio 189091 already downloaded.
# Audio 162847 already downloaded.
# Audio 161471 already downloaded.
# Audio 157864 already downloaded.
# Audio 149692 already downloaded.
# Audio 94804 already downloaded.
# Audio 74214 already downloaded.
# Audio 657073 already downloaded.
# Audio 630863 already downloaded.
# Audio 577870 already downloaded.
# Audio 574949 already downloaded.
# Audio 573354 already downloaded.
# Audio 573353 already downloaded.
# Audio 573351 already downloaded.
# Audio 573350 already downloaded.
# Audio 514070 already downloaded.
# Audio 460237 already downloaded.
# Audio 404214 already downloaded.
# Audio 369525 already downloaded.
# Audio 331546 already downloaded.
# Audio 308261 already downloaded.
# Audio 279623 already downloaded.
# Audio 269715 already downloaded.
# Audio 267344 already downloaded.
# Audio 209546 already downloaded.
# Audio 209008 already downloaded.
# Audio 207142 already downloaded.
# Audio 149691 already downloaded.
# Audio 149559 already downloaded.
# Audio 117098 already downloaded.
# Audio 116835 already downloaded.
# Audio 116834 already downloaded.
# Audio 116833 already downloaded.
# Audio 116832 already downloaded.
# Audio 116831 already downloaded.
# Audio 116830 already downloaded.
# Audio 79820 already downloaded.
# Audio 79818 already downloaded.
# Audio 74215 already downloaded.
# Audio 44915 already downloaded.
# Audio 336725 already downloaded.
# Audio 333682 already downloaded.
# Audio 79821 already downloaded.
# Audio 79819 already downloaded.
# Audio 331553 already downloaded.
# Audio 213138 already downloaded.
# Audio 187209 already downloaded.
# Audio 331556 already downloaded.
# Audio 187208 already downloaded.
# Audio 187206 already downloaded.
# Audio 547703 already downloaded.
# Audio 473044 already downloaded.
# Audio 441857 already downloaded.
# Audio 407528 already downloaded.
# Audio 99920 already downloaded.
# Audio 751065 already downloaded.
# Audio 213985 already downloaded.
# Audio 629645 already downloaded.
# Audio 460156 already downloaded.
# Audio 444185 already downloaded.
# Audio 444183 already downloaded.
# Audio 336393 already downloaded.
# Audio 336391 already downloaded.
# Audio 95174 already downloaded.
# Audio 44921 already downloaded.
# Audio 460170 already downloaded.
# Audio 460169 already downloaded.
# Audio 444184 already downloaded.
# Audio 369282 already downloaded.
# Audio 287465 already downloaded.
# Audio 212927 already downloaded.
# Audio 209198 already downloaded.
# Audio 196958 already downloaded.
# Audio 284854 already downloaded.
# Audio 369281 already downloaded.
# Audio 575121 already downloaded.
# Audio 571487 already downloaded.
# Audio 761717 already downloaded.
# Audio 508365 already downloaded.
# Audio 487524 already downloaded.
# Audio 472655 already downloaded.
# Audio 442867 already downloaded.
# Audio 426480 already downloaded.
# Audio 252597 already downloaded.
# Audio 212203 already downloaded.
# Audio 90657 already downloaded.
# Audio 432461 already downloaded.
# Audio 345158 already downloaded.
# Audio 604406 already downloaded.
# Audio 345160 already downloaded.
# Audio 442343 already downloaded.
# Audio 677383 already downloaded.
# Audio 677381 already downloaded.
# Audio 644024 already downloaded.
# Audio 644022 already downloaded.
# Audio 572395 already downloaded.
# Audio 531014 already downloaded.
# Audio 487795 already downloaded.
# Audio 426172 already downloaded.
# Audio 343013 already downloaded.
# Audio 191122 already downloaded.
# Audio 189336 already downloaded.
# Audio 165857 already downloaded.
# Audio 162840 already downloaded.
# Audio 161210 already downloaded.
# Audio 124017 already downloaded.
# Audio 585011 already downloaded.
# Audio 514026 already downloaded.
# Audio 472877 already downloaded.
# Audio 454033 already downloaded.
# Audio 426341 already downloaded.
# Audio 406117 already downloaded.
# Audio 369407 already downloaded.
# Audio 369406 already downloaded.
# Audio 215374 already downloaded.
# Audio 208672 already downloaded.
# Audio 196740 already downloaded.
# Audio 104137 already downloaded.
# Audio 21756 already downloaded.
# Audio 565301 already downloaded.
# Audio 208916 already downloaded.
# Audio 208327 already downloaded.
# Audio 196656 already downloaded.
# Audio 747634 already downloaded.
# Audio 777461 already downloaded.
# Audio 683308 already downloaded.
# Audio 788005 already downloaded.
# Audio 646845 already downloaded.
# Audio 592636 already downloaded.
# Audio 473848 already downloaded.
# Audio 473847 already downloaded.
# Audio 473846 already downloaded.
# Audio 473845 already downloaded.
# Audio 473844 already downloaded.
# Audio 473842 already downloaded.
# Audio 472985 already downloaded.
# Audio 460158 already downloaded.
# Audio 407497 already downloaded.
# Audio 383096 already downloaded.
# Audio 234154 already downloaded.
# Audio 195425 already downloaded.
# Audio 166343 already downloaded.
# Audio 116817 already downloaded.
# Audio 116816 already downloaded.
# Audio 44804 already downloaded.
# Audio 642745 already downloaded.
# Audio 592535 already downloaded.
# Audio 575214 already downloaded.
# Audio 575213 already downloaded.
# Audio 575212 already downloaded.
# Audio 268572 already downloaded.
# Audio 207255 already downloaded.
# Audio 197248 already downloaded.
# Audio 187435 already downloaded.
# Audio 166342 already downloaded.
# Audio 87721 already downloaded.
# Audio 592502 already downloaded.
# Audio 492386 already downloaded.
# Audio 452277 already downloaded.
# Audio 331900 already downloaded.
# Audio 654103 already downloaded.
# Audio 149589 already downloaded.
# Audio 149575 already downloaded.
# Audio 98667 already downloaded.
# Audio 654105 already downloaded.
# Audio 654104 already downloaded.
# Audio 460246 already downloaded.
# Audio 301692 already downloaded.
# Audio 211608 already downloaded.
# Audio 433678 already downloaded.
# Audio 390765 already downloaded.
# Audio 374624 already downloaded.
# Audio 343845 already downloaded.
# Audio 301411 already downloaded.
# Audio 188306 already downloaded.
# Audio 188305 already downloaded.
# Audio 187057 already downloaded.
# Audio 149599 already downloaded.
# Audio 149581 already downloaded.
# Audio 89745 already downloaded.
# Audio 541885 already downloaded.
# Audio 460184 already downloaded.
# Audio 630861 already downloaded.
# Audio 524303 already downloaded.
# Audio 409747 already downloaded.
# Audio 149605 already downloaded.
# Audio 94821 already downloaded.
# Audio 778601 already downloaded.
# Audio 630862 already downloaded.
# Audio 508362 already downloaded.
# Audio 508361 already downloaded.
# Audio 310426 already downloaded.
# Audio 654103 already downloaded.
# Audio 149589 already downloaded.
# Audio 149575 already downloaded.
# Audio 98667 already downloaded.
# Audio 654105 already downloaded.
# Audio 654104 already downloaded.
# Audio 460246 already downloaded.
# Audio 301692 already downloaded.
# Audio 211608 already downloaded.
# Downloading audio 460107...
# Downloading audio 213115...
# Downloading audio 213114...
# Downloading audio 94427...
# Downloading audio 19741...
# Downloading audio 576910...
# Downloading audio 576909...
# Downloading audio 497092...
# Downloading audio 497091...
# Downloading audio 369296...
# Downloading audio 308258...
# Downloading audio 209050...
# Downloading audio 209049...
# Downloading audio 209048...
# Downloading audio 194429...
# Downloading audio 97315...
# Downloading audio 529855...
# Downloading audio 471064...
# Downloading audio 166338...
# Downloading audio 166337...
# Downloading audio 166336...
# Downloading audio 166335...
# Downloading audio 443378...
# Downloading audio 638674...
# Downloading audio 547651...
# Downloading audio 472919...
# Downloading audio 472917...
# Downloading audio 472914...
# Downloading audio 472913...
# Downloading audio 460233...
# Downloading audio 460183...
# Downloading audio 454306...
# Downloading audio 417607...
# Downloading audio 407489...
# Downloading audio 347754...
# Downloading audio 304209...
# Downloading audio 128097...
# Downloading audio 787790...
# Downloading audio 785242...
# Downloading audio 785240...
# Downloading audio 775451...
# Downloading audio 775450...
# Downloading audio 638673...
# Downloading audio 547795...
# Downloading audio 547760...
# Downloading audio 547509...
# Downloading audio 532197...
# Downloading audio 529852...
# Downloading audio 529847...
# Downloading audio 529846...
# Downloading audio 472918...
# Downloading audio 460283...
# Downloading audio 460274...
# Downloading audio 460150...
# Downloading audio 426769...
# Downloading audio 314400...
# Downloading audio 308176...
# Downloading audio 165051...
# Downloading audio 149330...
# Downloading audio 128095...
# Downloading audio 116746...
# Downloading audio 116718...
# Downloading audio 116717...
# Downloading audio 116653...
# Downloading audio 116652...
# Downloading audio 116651...
# Downloading audio 116650...
# Downloading audio 73382...
# Downloading audio 638672...
# Downloading audio 632814...
# Downloading audio 360899...
# Downloading audio 128094...
# Downloading audio 106759...
# Downloading audio 105580...
# Downloading audio 91910...
# Downloading audio 73381...
# Downloading audio 19290...
# Downloading audio 116654...

# %%
def extract_max_energy(S, sr):
    # Remove noise
    S = librosa.decompose.nn_filter(S, aggregate=np.median, metric='cosine')

    # Find the 5-second window with the maximum energy
    window_size_frames =5* sr  // 512  # 512 is the default hop length used by librosa
    num_windows = S.shape[1] // window_size_frames
    #print(window_size_frames, num_windows)

    max_energy = 0
    max_start = 0
    for i in range(num_windows):
        start = i * window_size_frames
        end = start + window_size_frames
        energy = np.sum(S[:, start:end])
        if energy > max_energy:
            max_energy = energy
            max_start = start
    max_end = max_start + window_size_frames
   # print(max_start, max_end)
    # Extract the 5 seconds of spectrogram with maximum energy
    S_max_energy = S[:, max_start:max_end]

    return S_max_energy

# %%
df5['Spectrogram'] = None

# %%
df5
# Out:
#          id                   en                                    file  \
# 0    796874       Grey Francolin  https://xeno-canto.org/796874/download
# 7    472717       Grey Francolin  https://xeno-canto.org/472717/download
# 8    459199       Grey Francolin  https://xeno-canto.org/459199/download
# 9    441379       Grey Francolin  https://xeno-canto.org/441379/download
# 10   351857       Grey Francolin  https://xeno-canto.org/351857/download
# ..      ...                  ...                                     ...
# 666  105580  Hume's Leaf Warbler  https://xeno-canto.org/105580/download
# 667   91910  Hume's Leaf Warbler   https://xeno-canto.org/91910/download
# 668   73381  Hume's Leaf Warbler   https://xeno-canto.org/73381/download
# 669   19290  Hume's Leaf Warbler   https://xeno-canto.org/19290/download
# 670  116654  Hume's Leaf Warbler  https://xeno-canto.org/116654/download
#
#     length  Desert/Non-Desert Spectrogram
# 0     0:37                  1        None
# 7     0:16                  0        None
# 8     0:12                  0        None
# 9     0:07                  0        None
# 10    0:21                  1        None
# ..     ...                ...         ...
# 666   0:19                  0        None
# 667   0:05                  0        None
# 668   0:18                  0        None
# 669   0:33                  0        None
# 670   0:17                  0        None
#
# [462 rows x 6 columns]

# %%
import librosa.display as ld
spectrogram_dir = '/content/gdrive/MyDrive/spectrogram_data'


os.makedirs(spectrogram_dir, exist_ok=True)

for index, row in df5.iterrows():
    file_name = f"{row['id']}.mp3"
    file_path = os.path.join(data_dir, file_name)
    spectrogram_file = f"{row['id']}_spectrogram.npy"
    spectrogram_path = os.path.join(spectrogram_dir, spectrogram_file)

    # Check if spectrogram file exists, and if so, load it
    if os.path.isfile(spectrogram_path):
        S2 = np.load(spectrogram_path)
    else:
        # Load the audio file and compute the spectrogram
        y, sr = librosa.load(file_path)
        S = librosa.feature.melspectrogram(y=y, sr=sr)
        S2 = extract_max_energy(S, sr)  # Assuming extract_max_energy is defined
        np.save(spectrogram_path, S2)  # Save the extracted spectrogram

    # Plot the spectrogram (if needed)
    # ...
    # You can use the code you provided for plotting the spectrogram here

    df5.at[index, 'Spectrogram'] = S2
    '''
    # Plot the spectrogram
    plt.figure(figsize=(10, 4))
    ld.specshow(librosa.power_to_db(S2, ref=np.max), y_axis='mel', fmax=8000, x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title(f"{row['en']} ({row['Desert/Non-Desert']} Denoised)")
    plt.tight_layout()
    plt.show()
    plt.figure(figsize=(10, 4))
    ld.specshow(librosa.power_to_db(S, ref=np.max), y_axis='mel', fmax=8000, x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title(f"{row['en']} ({row['Desert/Non-Desert']})")
    plt.tight_layout()
    plt.show()
    '''
    df5.at[index, 'Spectrogram'] = S2

# %%
df5
# Out:
#          id                   en                                    file  \
# 0    796874       Grey Francolin  https://xeno-canto.org/796874/download
# 7    472717       Grey Francolin  https://xeno-canto.org/472717/download
# 8    459199       Grey Francolin  https://xeno-canto.org/459199/download
# 9    441379       Grey Francolin  https://xeno-canto.org/441379/download
# 10   351857       Grey Francolin  https://xeno-canto.org/351857/download
# ..      ...                  ...                                     ...
# 666  105580  Hume's Leaf Warbler  https://xeno-canto.org/105580/download
# 667   91910  Hume's Leaf Warbler   https://xeno-canto.org/91910/download
# 668   73381  Hume's Leaf Warbler   https://xeno-canto.org/73381/download
# 669   19290  Hume's Leaf Warbler   https://xeno-canto.org/19290/download
# 670  116654  Hume's Leaf Warbler  https://xeno-canto.org/116654/download
#
#     length  Desert/Non-Desert  \
# 0     0:37                  1
# 7     0:16                  0
# 8     0:12                  0
# 9     0:07                  0
# 10    0:21                  1
# ..     ...                ...
# 666   0:19                  0
# 667   0:05                  0
# 668   0:18                  0
# 669   0:33                  0
# 670   0:17                  0
#
#                                            Spectrogram
# 0    [[1.784749e-09, 1.9392543e-09, 1.7443029e-09, ...
# 7    [[0.0013777143, 0.0015780414, 0.0006839348, 0....
# 8    [[0.0196735, 0.011847297, 0.012750082, 0.01367...
# 9    [[0.13824023, 0.13824023, 0.13824023, 0.125113...
# 10   [[0.0027273414, 0.0025376135, 0.0024076584, 0....
# ..                                                 ...
# 666  [[0.051411375, 0.053026512, 0.04670254, 0.0598...
# 667  [[8.660332, 26.508755, 22.510593, 24.130413, 2...
# 668  [[0.2968467, 0.28199393, 0.21437094, 0.2054627...
# 669  [[0.0009708515, 0.0012644494, 0.001223997, 0.0...
# 670  [[0.07474666, 0.07193914, 0.07193914, 0.071939...
#
# [462 rows x 6 columns]

# %%
import pandas as pd
import datetime
# Convert duration to seconds
df5['duration_sec'] = df5['length'].apply(lambda x: datetime.datetime.strptime(x, '%M:%S').time())
df5['duration_sec'] = df5['duration_sec'].apply(lambda x: 60*x.minute + x.second)

# Remove rows with duration less than 5 seconds
df5 = df5[df5['duration_sec'] >= 5]

# Drop the duration_sec column
df5.drop('duration_sec', axis=1, inplace=True)
# Out:
# <ipython-input-87-dbfc86bfe691>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5.drop('duration_sec', axis=1, inplace=True)

# %%
df5
# Out:
#          id                   en                                    file  \
# 0    796874       Grey Francolin  https://xeno-canto.org/796874/download
# 7    472717       Grey Francolin  https://xeno-canto.org/472717/download
# 8    459199       Grey Francolin  https://xeno-canto.org/459199/download
# 9    441379       Grey Francolin  https://xeno-canto.org/441379/download
# 10   351857       Grey Francolin  https://xeno-canto.org/351857/download
# ..      ...                  ...                                     ...
# 666  105580  Hume's Leaf Warbler  https://xeno-canto.org/105580/download
# 667   91910  Hume's Leaf Warbler   https://xeno-canto.org/91910/download
# 668   73381  Hume's Leaf Warbler   https://xeno-canto.org/73381/download
# 669   19290  Hume's Leaf Warbler   https://xeno-canto.org/19290/download
# 670  116654  Hume's Leaf Warbler  https://xeno-canto.org/116654/download
#
#     length  Desert/Non-Desert  \
# 0     0:37                  1
# 7     0:16                  0
# 8     0:12                  0
# 9     0:07                  0
# 10    0:21                  1
# ..     ...                ...
# 666   0:19                  0
# 667   0:05                  0
# 668   0:18                  0
# 669   0:33                  0
# 670   0:17                  0
#
#                                            Spectrogram
# 0    [[1.784749e-09, 1.9392543e-09, 1.7443029e-09, ...
# 7    [[0.0013777143, 0.0015780414, 0.0006839348, 0....
# 8    [[0.0196735, 0.011847297, 0.012750082, 0.01367...
# 9    [[0.13824023, 0.13824023, 0.13824023, 0.125113...
# 10   [[0.0027273414, 0.0025376135, 0.0024076584, 0....
# ..                                                 ...
# 666  [[0.051411375, 0.053026512, 0.04670254, 0.0598...
# 667  [[8.660332, 26.508755, 22.510593, 24.130413, 2...
# 668  [[0.2968467, 0.28199393, 0.21437094, 0.2054627...
# 669  [[0.0009708515, 0.0012644494, 0.001223997, 0.0...
# 670  [[0.07474666, 0.07193914, 0.07193914, 0.071939...
#
# [425 rows x 6 columns]

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #t-test#

# %%
desert_spectrograms=[]
non_desert_spectrograms=[]

# %%
df5
# Out:
#          id                   en                                    file  \
# 0    796874       Grey Francolin  https://xeno-canto.org/796874/download
# 7    472717       Grey Francolin  https://xeno-canto.org/472717/download
# 8    459199       Grey Francolin  https://xeno-canto.org/459199/download
# 9    441379       Grey Francolin  https://xeno-canto.org/441379/download
# 10   351857       Grey Francolin  https://xeno-canto.org/351857/download
# ..      ...                  ...                                     ...
# 666  105580  Hume's Leaf Warbler  https://xeno-canto.org/105580/download
# 667   91910  Hume's Leaf Warbler   https://xeno-canto.org/91910/download
# 668   73381  Hume's Leaf Warbler   https://xeno-canto.org/73381/download
# 669   19290  Hume's Leaf Warbler   https://xeno-canto.org/19290/download
# 670  116654  Hume's Leaf Warbler  https://xeno-canto.org/116654/download
#
#     length  Desert/Non-Desert  \
# 0     0:37                  1
# 7     0:16                  0
# 8     0:12                  0
# 9     0:07                  0
# 10    0:21                  1
# ..     ...                ...
# 666   0:19                  0
# 667   0:05                  0
# 668   0:18                  0
# 669   0:33                  0
# 670   0:17                  0
#
#                                            Spectrogram
# 0    [[1.784749e-09, 1.9392543e-09, 1.7443029e-09, ...
# 7    [[0.0013777143, 0.0015780414, 0.0006839348, 0....
# 8    [[0.0196735, 0.011847297, 0.012750082, 0.01367...
# 9    [[0.13824023, 0.13824023, 0.13824023, 0.125113...
# 10   [[0.0027273414, 0.0025376135, 0.0024076584, 0....
# ..                                                 ...
# 666  [[0.051411375, 0.053026512, 0.04670254, 0.0598...
# 667  [[8.660332, 26.508755, 22.510593, 24.130413, 2...
# 668  [[0.2968467, 0.28199393, 0.21437094, 0.2054627...
# 669  [[0.0009708515, 0.0012644494, 0.001223997, 0.0...
# 670  [[0.07474666, 0.07193914, 0.07193914, 0.071939...
#
# [425 rows x 6 columns]

# %%
'''
import os
import requests
from scipy.stats import *
for species in df5['en'].unique():
    desert_spectrograms=[]
    non_desert_spectrograms=[]
    for index,row in df5[df5['en'] == species].iterrows():
        file_name = f"{row['id']}.mp3"
        file_path = os.path.join(data_dir, file_name)

        # Check if audio file exists, and if not, download it
        if not os.path.isfile(file_path):
          audio_url = 'https:'+row['file']
          audio_data = requests.get(audio_url).content
          with open(file_path, 'wb') as handler:
              handler.write(audio_data)

        # Load audio file

        try:
            y, sr = librosa.load(file_path)
        except Exception as e:
            print(f"Error loading audio file: {e}")
            continue



        S = librosa.feature.melspectrogram(y=y, sr=sr)
        S2 = extract_max_energy(S, sr)

        if row['Desert/Non-Desert']==1:
            desert_spectrograms.append(S2)
        else:
            non_desert_spectrograms.append(S2)

      # Check if the length of either desert or non-desert spectrograms is zero and continue to the next species if so
    if len(desert_spectrograms) == 0 or len(non_desert_spectrograms) == 0:
      continue
    print(len(desert_spectrograms),len(non_desert_spectrograms))
    # Compute the average power in different frequency bands for each region (replace with your own frequency bands)


    # ...
    # Compute the average power in different frequency bands for each region (replace with your own frequency bands)
    desert_freq = np.mean(np.abs(desert_spectrograms)**2, axis=1)
    non_desert_freq = np.mean(np.abs(non_desert_spectrograms)**2, axis=1)

    # Convert the mean power values to decibels
    desert_freq_db = 10 * np.log10(desert_freq)
    non_desert_freq_db = 10 * np.log10(non_desert_freq)

    # Compute the frequency range of the spectrograms
    freq_range = np.linspace(0, 22050/2, 215)

    # Plot the mean frequency content for each region in decibels
    fig, ax = plt.subplots()
    ax.plot(freq_range, np.mean(desert_freq_db, axis=0), label='Desert')
    ax.plot(freq_range, np.mean(non_desert_freq_db, axis=0), label='Non-Desert')

    ax.set_xlabel('Frequency (Hz)')
    ax.set_ylabel('Mean Power (dB)')
    ax.set_title(f'Mean Frequency Content for Desert and Non-Desert Regions {species} (dB)')
    ax.legend()
    plt.show()

    # Perform a two-sample t-test to compare the mean frequency content between the two regions
    t_stat, p_value = ttest_ind(desert_freq_db.flatten(), non_desert_freq_db.flatten(), equal_var=False)

    print('T-statistic:', t_stat)
    print('P-value:', p_value)
'''
# Out:
# '\nimport os\nimport requests\nfrom scipy.stats import *\nfor species in df5[\'en\'].unique():\n    desert_spectrograms=[]\n    non_desert_spectrograms=[]\n    for index,row in df5[df5[\'en\'] == species].iterrows():\n        file_name = f"{row[\'id\']}.mp3"\n        file_path = os.path.join(data_dir, file_name)\n        \n        # Check if audio file exists, and if not, download it\n        if not os.path.isfile(file_path):\n          audio_url = \'https:\'+row[\'file\']\n          audio_data = requests.get(audio_url).content\n          with open(file_path, \'wb\') as handler:\n              handler.write(audio_data)\n\n        # Load audio file\n              \n        try:\n            y, sr = librosa.load(file_path)\n        except Exception as e:\n            print(f"Error loading audio file: {e}")\n            continue\n\n\n\n        S = librosa.feature.melspectrogram(y=y, sr=sr)\n        S2 = extract_max_energy(S, sr)\n\n        if row[\'Desert/Non-Desert\']==1:\n            desert_spectrograms.append(S2)\n        else:\n            non_desert_spectrograms.append(S2)\n          \n      # Check if the length of either desert or non-desert spectrograms is zero and continue to the next species if so\n    if len(desert_spectrograms) == 0 or len(non_desert_spectrograms) == 0:\n      continue\n    print(len(desert_spectrograms),len(non_desert_spectrograms))\n    # Compute the average power in different frequency bands for each region (replace with your own frequency bands)\n    \n\n    # ...\n    # Compute the average power in different frequency bands for each region (replace with your own frequency bands)\n    desert_freq = np.mean(np.abs(desert_spectrograms)**2, axis=1)\n    non_desert_freq = np.mean(np.abs(non_desert_spectrograms)**2, axis=1)\n\n    # Convert the mean power values to decibels\n    desert_freq_db = 10 * np.log10(desert_freq)\n    non_desert_freq_db = 10 * np.log10(non_desert_freq)\n\n    # Compute the frequency range of the spectrograms\n    freq_range = np.linspace(0, 22050/2, 215)\n\n    # Plot the mean frequency content for each region in decibels\n    fig, ax = plt.subplots()\n    ax.plot(freq_range, np.mean(desert_freq_db, axis=0), label=\'Desert\')\n    ax.plot(freq_range, np.mean(non_desert_freq_db, axis=0), label=\'Non-Desert\')\n\n    ax.set_xlabel(\'Frequency (Hz)\')\n    ax.set_ylabel(\'Mean Power (dB)\')\n    ax.set_title(f\'Mean Frequency Content for Desert and Non-Desert Regions {species} (dB)\')\n    ax.legend()\n    plt.show()\n\n    # Perform a two-sample t-test to compare the mean frequency content between the two regions\n    t_stat, p_value = ttest_ind(desert_freq_db.flatten(), non_desert_freq_db.flatten(), equal_var=False)\n\n    print(\'T-statistic:\', t_stat)\n    print(\'P-value:\', p_value)\n'

# %% [markdown]
# #Autoencoder#

# %%
df5
# Out:
#          id                   en                                    file  \
# 0    796874       Grey Francolin  https://xeno-canto.org/796874/download
# 7    472717       Grey Francolin  https://xeno-canto.org/472717/download
# 8    459199       Grey Francolin  https://xeno-canto.org/459199/download
# 9    441379       Grey Francolin  https://xeno-canto.org/441379/download
# 10   351857       Grey Francolin  https://xeno-canto.org/351857/download
# ..      ...                  ...                                     ...
# 666  105580  Hume's Leaf Warbler  https://xeno-canto.org/105580/download
# 667   91910  Hume's Leaf Warbler   https://xeno-canto.org/91910/download
# 668   73381  Hume's Leaf Warbler   https://xeno-canto.org/73381/download
# 669   19290  Hume's Leaf Warbler   https://xeno-canto.org/19290/download
# 670  116654  Hume's Leaf Warbler  https://xeno-canto.org/116654/download
#
#     length  Desert/Non-Desert  \
# 0     0:37                  1
# 7     0:16                  0
# 8     0:12                  0
# 9     0:07                  0
# 10    0:21                  1
# ..     ...                ...
# 666   0:19                  0
# 667   0:05                  0
# 668   0:18                  0
# 669   0:33                  0
# 670   0:17                  0
#
#                                            Spectrogram
# 0    [[1.784749e-09, 1.9392543e-09, 1.7443029e-09, ...
# 7    [[0.0013777143, 0.0015780414, 0.0006839348, 0....
# 8    [[0.0196735, 0.011847297, 0.012750082, 0.01367...
# 9    [[0.13824023, 0.13824023, 0.13824023, 0.125113...
# 10   [[0.0027273414, 0.0025376135, 0.0024076584, 0....
# ..                                                 ...
# 666  [[0.051411375, 0.053026512, 0.04670254, 0.0598...
# 667  [[8.660332, 26.508755, 22.510593, 24.130413, 2...
# 668  [[0.2968467, 0.28199393, 0.21437094, 0.2054627...
# 669  [[0.0009708515, 0.0012644494, 0.001223997, 0.0...
# 670  [[0.07474666, 0.07193914, 0.07193914, 0.071939...
#
# [425 rows x 6 columns]

# %%
# Filter the rows where 'Desert/Non-Desert' is 1 (desert species)
all_desert_spectrograms = df5.loc[df5['Desert/Non-Desert'] == 1, 'Spectrogram'].tolist()

# Filter the rows where 'Desert/Non-Desert' is not 1 (non-desert species)
all_non_desert_spectrograms = df5.loc[df5['Desert/Non-Desert'] != 1, 'Spectrogram'].tolist()

# Continue with further processing using all_desert_spectrograms and all_non_desert_spectrograms

# %%
import numpy as np
from keras.models import Model
from keras.layers import Input, Dense
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Combine desert and non-desert spectrograms into a single dataset
all_spectrograms = np.concatenate((all_desert_spectrograms, all_non_desert_spectrograms), axis=0)

# Flatten the spectrograms for use with a fully connected autoencoder
all_spectrograms_flat = all_spectrograms.reshape((all_spectrograms.shape[0], -1))

# Normalize the data to the [0, 1] range
scaler = MinMaxScaler()
all_spectrograms_flat = scaler.fit_transform(all_spectrograms_flat)

# Split the data into training and testing sets
X_train, X_test = train_test_split(all_spectrograms_flat, test_size=0.2, random_state=42)

# Define the autoencoder architecture
input_dim = X_train.shape[1]
encoding_dim = 12  # Dimension of the encoded representation

# Input layer
input_spectrogram = Input(shape=(input_dim,))

# Encoding layers
encoded = Dense(encoding_dim, activation='relu')(input_spectrogram)
encoded = Dense(encoding_dim // 2, activation='relu')(encoded)

# Decoding layers
decoded = Dense(encoding_dim, activation='relu')(encoded)
decoded = Dense(input_dim, activation='linear')(decoded)  # Use linear activation

# Define the autoencoder model
autoencoder = Model(input_spectrogram, decoded)

# Define the encoder model (for encoding the data)
encoder = Model(input_spectrogram, encoded)

# Compile the autoencoder
autoencoder.compile(optimizer=Adam(lr=0.001), loss='mse')  # Use a smaller learning rate

# Train the autoencoder
autoencoder.fit(X_train, X_train,
                epochs=50,
                batch_size=32,
                shuffle=True,
                validation_data=(X_test, X_test))

# Encode and decode the test data
encoded_spectrograms = encoder.predict(X_test)
decoded_spectrograms = autoencoder.predict(X_test)

# Reshape the decoded spectrograms to their original shape
decoded_spectrograms = decoded_spectrograms.reshape((-1, all_spectrograms.shape[1], all_spectrograms.shape[2]))

# ... You can now visualize and analyze the encoded and decoded spectrograms
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 11/11 [==============================] - 1s 38ms/step - loss: 0.0045 - val_loss: 0.0048
# Epoch 2/50
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 3/50
# 11/11 [==============================] - 0s 25ms/step - loss: 0.0044 - val_loss: 0.0046
# Epoch 4/50
# 11/11 [==============================] - 0s 24ms/step - loss: 0.0042 - val_loss: 0.0040
# Epoch 5/50
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 6/50
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 7/50
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0043 - val_loss: 0.0040
# Epoch 8/50
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 9/50
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 10/50
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 11/50
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0037 - val_loss: 0.0040
# Epoch 12/50
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 13/50
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0035 - val_loss: 0.0039
# Epoch 14/50
# 11/11 [==============================] - 0s 26ms/step - loss: 0.0034 - val_loss: 0.0039
# Epoch 15/50
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0034 - val_loss: 0.0039
# Epoch 16/50
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0034 - val_loss: 0.0039
# Epoch 17/50
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 18/50
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 19/50
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 20/50
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 21/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 22/50
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 23/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 24/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 25/50
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 26/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 27/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 28/50
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 29/50
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 30/50
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 31/50
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 32/50
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 33/50
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 34/50
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 35/50
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 36/50
# 11/11 [==============================] - 0s 35ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 37/50
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 38/50
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0032 - val_loss: 0.0039
# Epoch 39/50
# 11/11 [==============================] - 0s 31ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 40/50
# 11/11 [==============================] - 0s 34ms/step - loss: 0.0032 - val_loss: 0.0039
# Epoch 41/50
# 11/11 [==============================] - 0s 32ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 42/50
# 11/11 [==============================] - 0s 30ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 43/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 44/50
# 11/11 [==============================] - 0s 23ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 45/50
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0032 - val_loss: 0.0038
# Epoch 46/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 47/50
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 48/50
# 11/11 [==============================] - 0s 22ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 49/50
# 11/11 [==============================] - 0s 21ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 50/50
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0031 - val_loss: 0.0038
# 3/3 [==============================] - 0s 8ms/step
# 3/3 [==============================] - 0s 13ms/step

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Split the data into training and testing sets, and keep track of the indices
X_train, X_test, train_indices, test_indices = train_test_split(
    all_spectrograms_flat, np.arange(all_spectrograms_flat.shape[0]), test_size=0.2, random_state=42
)

# Train the autoencoder and obtain encoded_spectrograms (as in your previous code)

# Perform t-SNE on the encoded spectrograms
tsne = TSNE(n_components=2, random_state=42)
tsne_results = tsne.fit_transform(encoded_spectrograms)

# Get the labels for the test data (desert or non-desert) for visualization
test_labels = df5.loc[df5.index.isin(df5.index[test_indices]), 'Desert/Non-Desert']

# Plot the t-SNE results
plt.figure(figsize=(8, 6))
plt.scatter(tsne_results[test_labels == 1, 0], tsne_results[test_labels == 1, 1], label='Desert', alpha=0.7)
plt.scatter(tsne_results[test_labels != 1, 0], tsne_results[test_labels != 1, 1], label='Non-Desert', alpha=0.7)
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.title('t-SNE Visualization of Encoded Spectrograms')
plt.legend()
plt.show()
